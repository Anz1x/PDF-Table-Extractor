# %%
import camelot as cm

# %%
! dir
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 7242-E1DB
#
#  Directory of C:\Users\anand\Codes\Python Codes\PDF-Table-Extractor
#
# 12/06/2022  01:13 PM    <DIR>          .
# 07/06/2022  07:53 PM    <DIR>          ..
# 12/06/2022  01:00 PM    <DIR>          .ipynb_checkpoints
# 07/06/2022  07:39 PM           850,276 india_factsheet_economic_n_hdi.pdf
# 12/06/2022  01:13 PM            22,524 PDF-Table-Extractor.ipynb
# 12/06/2022  01:00 PM            22,510 pdftable_extractor.ipynb
# 12/06/2022  01:12 PM            35,190 pdftable_extractor.py
#                4 File(s)        930,500 bytes
#                3 Dir(s)  105,878,102,016 bytes free

# %%
input_pdf = cm.read_pdf("india_factsheet_economic_n_hdi.pdf",flavor='stream',pages='1,2')

# %%
for i in input_pdf:
    print(i)
# Out:
# <Table shape=(35, 4)>
# <Table shape=(22, 4)>
# <Table shape=(16, 4)>
# <Table shape=(26, 2)>

# %%
input_pdf[0].df
# Out:
#                                             0  \
# 0   Economic and Human Development Indicators
# 1
# 2
# 3                                           1
# 4                                           2
# 5                                           3
# 6
# 7                                           4
# 8
# 9                                           5
# 10                                          6
# 11                                          7
# 12
# 13                                          8
# 14
# 15                                          9
# 16
# 17                                         10
# 18                                         11
# 19
# 20                                         12
# 21
# 22                                         13
# 23                                         14
# 24                                         15
# 25                                         16
# 26
# 27                                         17
# ...

# %%
df = input_pdf[0].df.loc[32:35,1:3]

# %%
df
# Out:
#                            1     2      3
# 32         Literacy Rate (%)  64.8  74.04
# 33    Male Literacy Rate (%)  75.3  82.14
# 34  Female Literacy Rate (%)  53.7  65.46

# %%
df = df.reset_index(drop = True)

# %%
df
# Out:
#                           1     2      3
# 0         Literacy Rate (%)  64.8  74.04
# 1    Male Literacy Rate (%)  75.3  82.14
# 2  Female Literacy Rate (%)  53.7  65.46

# %%
df.columns = ["KPI","2001","2011"]

# %%
df
# Out:
#                         KPI  2001   2011
# 0         Literacy Rate (%)  64.8  74.04
# 1    Male Literacy Rate (%)  75.3  82.14
# 2  Female Literacy Rate (%)  53.7  65.46

# %%
df.loc[0:2,["2001","2011"]] = df.loc[0:2,["2001","2011"]].astype(float)

# %%
df
# Out:
#                         KPI  2001   2011
# 0         Literacy Rate (%)  64.8  74.04
# 1    Male Literacy Rate (%)  75.3  82.14
# 2  Female Literacy Rate (%)  53.7  65.46

# %%
df.to_csv("pdf_output.csv")

# %%
! dir
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 7242-E1DB
#
#  Directory of C:\Users\anand\Codes\Python Codes\PDF-Table-Extractor
#
# 12/06/2022  01:16 PM    <DIR>          .
# 07/06/2022  07:53 PM    <DIR>          ..
# 12/06/2022  01:00 PM    <DIR>          .ipynb_checkpoints
# 07/06/2022  07:39 PM           850,276 india_factsheet_economic_n_hdi.pdf
# 12/06/2022  01:16 PM            24,934 PDF-Table-Extractor.ipynb
# 12/06/2022  01:00 PM            22,510 pdftable_extractor.ipynb
# 12/06/2022  01:12 PM            35,190 pdftable_extractor.py
# 12/06/2022  01:16 PM               124 pdf_output.csv
#                5 File(s)        933,034 bytes
#                3 Dir(s)  105,854,152,704 bytes free

# %%
df.to_excel("pdf_table.xlsx")
